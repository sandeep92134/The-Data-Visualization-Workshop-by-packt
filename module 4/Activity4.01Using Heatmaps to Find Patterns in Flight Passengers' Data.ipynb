# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep92134/The-Data-Visualization-Workshop-by-packt/blob/master/module%204/Activity4.01Using%20Heatmaps%20to%20Find%20Patterns%20in%20Flight%20Passengers'%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Activity 4.01: Using Heatmaps to Find Patterns in Flight Passengers' Data
# In this activity, we will use a heatmap to find patterns in flight passenger data. The goal of this activity is to apply your knowledge about color palettes to choose a suitable color palette for this data.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# Use pandas to read the dataset flight_details.csv located in the Dataset folder. The given dataset contains the monthly figures for flight passengers from the years 1949 to 1960.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/sandeep92134/The-Data-Visualization-Workshop-by-packt/master/module%204/datasets/flight_details.csv")

# %% [markdown]
# Now, we can use the pivot() function to transform the data to a format which is suitable for heatmaps.

# %%
data = data.pivot("Months", "Years", "Passengers")

# %%
data = data.reindex(['January', 'February', 'March', 'April', 'May', 'June',
                     'July', 'August', 'September', 'October', 'November', 'December'])

# %% [markdown]
# Use a heatmap to visualize the given data. The given dataset contains the monthly figures for flight passengers for multiple years. Use your own appropriate color map. Make sure that the lowest value is the brightest and the highest the darkest color.

# %%
plt.figure(dpi=250)
sns.heatmap(data, cmap=sns.cubehelix_palette(rot=-.3, as_cmap=True)) # you can use any sequential color palette
plt.title("Flight Passengers from 1949 to 1960")
plt.show()
